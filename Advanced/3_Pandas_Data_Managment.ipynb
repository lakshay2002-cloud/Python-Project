# %%
import pandas as pd 
import matplotlib.pyplot as plt 

data = pd.read_csv(r"C:\Users\Lenovo\OneDrive\Documents\Projects\Luke Barousse Projects\Python Course  Data Analysis\data_jobs.csv")
df=data

# %%
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#             job_title_short                               job_title  \
# 328376     Business Analyst           Business Intelligence Analyst
# 278572         Data Analyst  CE ONLINE CAPACITY & REPORTING ANALYST
# 270842       Data Scientist                          Data Scientist
# 35441         Data Engineer                       Big Data Engineer
# 438542  Senior Data Analyst                     Senior Data Analyst
# 308047       Data Scientist                          Data Scientist
# 37639        Data Scientist          Alternant Data Scientist (H/F)
# 396057        Data Engineer                           Data Engineer
# 264433       Data Scientist              (USA) Staff Data Scientist
# 438883        Data Engineer                           Data Engineer
#
#                job_location              job_via job_schedule_type  \
# 328376       Kraków, Poland      via Recruit.net         Full-time
# 278572      Prague, Czechia         via LinkedIn         Full-time
# 270842     Indianapolis, IN         via LinkedIn        Contractor
# 35441   Zürich, Switzerland  via UBS - Talentify         Full-time
# 438542           McLean, VA            via BeBee         Full-time
# 308047            Tampa, FL            via BeBee         Full-time
# 37639    Courbevoie, France         via Jobijoba         Part-time
# 396057       United Kingdom            via BeBee         Full-time
# 264433      Bentonville, AR            via BeBee         Full-time
# 438883     Cologne, Germany            via BeBee         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 328376               False                   Poland 2023-01-03 23:44:43
# 278572               False                  Czechia 2023-02-10 14:16:23
# 270842               False                  Georgia 2023-06-02 13:44:50
# 35441                False              Switzerland 2023-03-22 07:38:31
# 438542               False  New York, United States 2023-08-28 00:00:20
# 308047               False   Florida, United States 2023-02-17 14:06:39
# 37639                False                   France 2023-06-02 07:39:41
# 396057               False           United Kingdom 2023-10-07 09:10:10
# 264433               False     Texas, United States 2023-01-01 13:05:28
# 438883               False                  Germany 2023-10-06 00:14:47
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 328376                  False                 False          Poland
# 278572                   True                 False         Czechia
# 270842                  False                 False   United States
# 35441                    True                 False     Switzerland
# 438542                  False                 False   United States
# 308047                  False                  True   United States
# 37639                   False                 False          France
# 396057                   True                 False  United Kingdom
# 264433                  False                  True   United States
# 438883                  False                 False         Germany
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 328376         NaN              NaN              NaN
# 278572         NaN              NaN              NaN
# 270842         NaN              NaN              NaN
# 35441          NaN              NaN              NaN
# 438542         NaN              NaN              NaN
# 308047         NaN              NaN              NaN
# 37639          NaN              NaN              NaN
# 396057         NaN              NaN              NaN
# 264433         NaN              NaN              NaN
# 438883         NaN              NaN              NaN
#
#                                 company_name  \
# 328376                             Kongsberg
# 278572                  Tesco Czech Republic
# 270842         Swift Strategic Solutions Inc
# 35441                                    UBS
# 438542                  Vault Consulting LLC
# 308047                             STEMBoard
# 37639                          Credit Mutuel
# 396057             Understanding Recruitment
# 264433                   Walmart Global Tech
# 438883  Lufthansa Industry Solutions AS GmbH
#
#                                                job_skills  \
# 328376  ['vba', 'sql', 'power bi', 'excel', 'cognos', ...
# 278572              ['sql', 'hadoop', 'excel', 'alteryx']
# 270842                                 ['sql', 'tableau']
# 35441   ['python', 'scala', 'java', 'sql', 'nosql', 'm...
# 438542             ['python', 'excel', 'tableau', 'qlik']
# 308047  ['r', 'python', 'sql', 'databricks', 'ibm clou...
# 37639                      ['vba', 'sas', 'sas', 'excel']
# 396057                     ['sql', 'databricks', 'azure']
# 264433  ['python', 'r', 'sql', 'nosql', 'scala', 'spar...
# 438883                                                NaN
#
#                                           job_type_skills
# 328376  {'analyst_tools': ['power bi', 'excel', 'cogno...
# 278572  {'analyst_tools': ['excel', 'alteryx'], 'libra...
# 270842  {'analyst_tools': ['tableau'], 'programming': ...
# 35441   {'cloud': ['azure', 'aws', 'databricks', 'orac...
# 438542  {'analyst_tools': ['excel', 'tableau', 'qlik']...
# 308047  {'analyst_tools': ['tableau', 'power bi'], 'cl...
# 37639   {'analyst_tools': ['sas', 'excel'], 'programmi...
# 396057  {'cloud': ['databricks', 'azure'], 'programmin...
# 264433  {'libraries': ['spark', 'tensorflow'], 'progra...
# 438883                                                NaN

# %%
df.sample(10,random_state=42)
# Out:
#             job_title_short  \
# 1367          Data Engineer
# 410489        Data Engineer
# 79653          Data Analyst
# 653306         Data Analyst
# 437702        Data Engineer
# 592915       Data Scientist
# 764702     Business Analyst
# 83372      Business Analyst
# 611950  Senior Data Analyst
# 29742        Data Scientist
#
#                                                 job_title  \
# 1367                       Data Engineer AWS confirmé H/F
# 410489   BP²I - DATA Engineer / Développeur Tableau - H/F
# 79653               Senior Sales & Marketing Data Analyst
# 653306  VP - Portfolio Credit Data Analytics Manager -...
# 437702                                      Data Engineer
# 592915                             Data Scientist, Junior
# 764702                                Power BI Consultant
# 83372                        Technical Support Engineer 1
# 611950                                Senior FP&A Analyst
# 29742                              Data Scientist  - HTHD
#
#                       job_location                  job_via  \
# 1367                 Lille, France             via Jobijoba
# 410489           Montreuil, France    via EFinancialCareers
# 79653        Tel Aviv-Yafo, Israel             via LinkedIn
# 653306                  Irving, TX             via LinkedIn
# 437702                    Anywhere              via EMPREGO
# 592915             Los Angeles, CA                via BeBee
# 764702           Mechelen, Belgium       via BeBee Belgique
# 83372          Montpellier, France  via Emplois Trabajo.org
# 611950                   Miami, FL          via Trabajo.org
# 29742   Chennai, Tamil Nadu, India               via Oracle
#
#               job_schedule_type  job_work_from_home  \
# 1367                  Full-time               False
# 410489                Full-time               False
# 79653                 Full-time               False
# 653306                Full-time               False
# 437702                Full-time                True
# 592915  Part-time and Temp work               False
# 764702                Full-time               False
# 83372                 Full-time               False
# 611950                Full-time               False
# 29742                 Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 1367                       France 2023-06-24 07:23:19                  False
# 410489                     France 2023-04-29 09:19:36                  False
# 79653                      Israel 2023-05-14 20:33:19                  False
# 653306       Texas, United States 2023-03-08 12:01:10                  False
# 437702                      Italy 2023-03-09 00:19:48                  False
# 592915  California, United States 2023-10-25 22:03:58                  False
# 764702                    Belgium 2023-09-18 01:20:22                   True
# 83372                      France 2023-02-25 20:58:43                  False
# 611950     Florida, United States 2023-04-24 04:02:37                   True
# 29742                       India 2023-09-21 07:07:32                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 1367                   False         France         NaN              NaN
# 410489                 False         France         NaN              NaN
# 79653                  False         Israel         NaN              NaN
# 653306                 False  United States         NaN              NaN
# 437702                 False          Italy         NaN              NaN
# 592915                  True  United States         NaN              NaN
# 764702                 False        Belgium         NaN              NaN
# 83372                  False         France         NaN              NaN
# 611950                 False  United States         NaN              NaN
# 29742                  False          India         NaN              NaN
#
#         salary_hour_avg             company_name  \
# 1367                NaN                   skiils
# 410489              NaN              BNP Paribas
# 79653               NaN                    HiBob
# 653306              NaN                     Citi
# 437702              NaN            Confidenziale
# 592915              NaN              Blue Origin
# 764702              NaN                Datashift
# 83372               NaN                 Taleo BE
# 611950              NaN            Launch Potato
# 29742               NaN  Ford Global Career Site
#
#                                                job_skills  \
# 1367    ['sql', 'python', 'nosql', 'scala', 'aws', 'sn...
# 410489  ['sql', 'sql server', 'postgresql', 'oracle', ...
# 79653                         ['sql', 'tableau', 'excel']
# 653306                                                NaN
# 437702                       ['nosql', 'mysql', 'oracle']
# 592915                                ['python', 'excel']
# 764702                                       ['power bi']
# 83372            ['vmware', 'windows', 'redhat', 'linux']
# 611950                                ['excel', 'looker']
# 29742                 ['nosql', 'gcp', 'hadoop', 'spark']
#
#                                           job_type_skills
# 1367    {'cloud': ['aws', 'snowflake', 'databricks'], ...
# 410489  {'analyst_tools': ['tableau', 'power bi', 'cog...
# 79653   {'analyst_tools': ['tableau', 'excel'], 'progr...
# 653306                                                NaN
# 437702  {'cloud': ['oracle'], 'databases': ['mysql'], ...
# 592915  {'analyst_tools': ['excel'], 'programming': ['...
# 764702                    {'analyst_tools': ['power bi']}
# 83372   {'cloud': ['vmware'], 'os': ['windows', 'redha...
# 611950             {'analyst_tools': ['excel', 'looker']}
# 29742   {'cloud': ['gcp'], 'libraries': ['hadoop', 'sp...

# %%
df_copy=df.copy()

# %%
id(df_copy) == id(df)
# Out:
# False

# %%
df_fake = df

# %%
id(df) == id(df_fake)
# Out:
# True
