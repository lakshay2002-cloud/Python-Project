# %%
import pandas as pd 
import matplotlib.pyplot as plt 

data = pd.read_csv(r"C:\Users\Lenovo\OneDrive\Documents\Projects\Luke Barousse Projects\Python Course  Data Analysis\data_jobs.csv")
df=data
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# Count of Job Title

# %%
df.pivot_table(index='job_title_short',aggfunc='size')
# Out:
# job_title_short
# Business Analyst              49160
# Cloud Engineer                12346
# Data Analyst                 196593
# Data Engineer                186678
# Data Scientist               172727
# Machine Learning Engineer     14106
# Senior Data Analyst           29289
# Senior Data Engineer          44692
# Senior Data Scientist         37076
# Software Engineer             45019
# dtype: int64

# %%
df.groupby('job_title_short').size()
# Out:
# job_title_short
# Business Analyst              49160
# Cloud Engineer                12346
# Data Analyst                 196593
# Data Engineer                186678
# Data Scientist               172727
# Machine Learning Engineer     14106
# Senior Data Analyst           29289
# Senior Data Engineer          44692
# Senior Data Scientist         37076
# Software Engineer             45019
# dtype: int64

# %%
df.pivot_table(values = 'salary_year_avg',index='job_title_short',aggfunc='median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    128000.0
# Machine Learning Engineer         106000.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155000.0
# Software Engineer                  99150.0

# %%
df.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               128000.0
# Machine Learning Engineer    106000.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155000.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df.pivot_table(values = 'salary_year_avg',index='job_country',columns='job_title_short' ,aggfunc='median')
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        200750.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 96500.0        110000.0     100500.00
# ...                           ...             ...           ...
# United States             90000.0        115000.0      90000.00
# Uruguay                       NaN             NaN     100500.00
# Vietnam                   79200.0             NaN      75550.00
# Zambia                        NaN             NaN           NaN
# Zimbabwe                      NaN             NaN      63000.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# Algeria                45000.0             NaN                        NaN
# Argentina              96773.0        71000.00                   101029.0
# Armenia                45000.0             NaN                    87021.0
# Australia             102425.0       139216.00                   101029.0
# ...                        ...             ...                        ...
# United States         125000.0       130000.00                   150000.0
# Uruguay                    NaN             NaN                        NaN
# Vietnam                96773.0        70000.00                    57600.0
# Zambia                     NaN        90670.00                        NaN
# Zimbabwe                   NaN        69085.00                        NaN
#
# job_title_short  Senior Data Analyst  Senior Data Engineer  \
# job_country
# Albania                          NaN                   NaN
# Algeria                          NaN                   NaN
# Argentina                        NaN              147500.0
# Armenia                          NaN                   NaN
# Australia                    50640.0              147500.0
# ...                              ...                   ...
# United States               110000.0              150000.0
# Uruguay                          NaN                   NaN
# Vietnam                     105837.5              147500.0
# Zambia                           NaN                   NaN
# Zimbabwe                         NaN                   NaN
#
# job_title_short  Senior Data Scientist  Software Engineer
# job_country
# Albania                       157500.0                NaN
# Algeria                            NaN                NaN
# Argentina                          NaN                NaN
# Armenia                            NaN                NaN
# Australia                     157500.0           157500.0
# ...                                ...                ...
# United States                 155000.0           125000.0
# Uruguay                        57500.0            85000.0
# Vietnam                        79200.0            53600.0
# Zambia                             NaN                NaN
# Zimbabwe                           NaN                NaN
#
# [103 rows x 10 columns]

# %%
top_countries = df['job_country'].value_counts().head(6).index

df_job_country_salary = df.pivot_table(
    values='salary_year_avg',
    index='job_country',
    columns='job_title_short',
    aggfunc='median'
)

df_job_country_salary = df_job_country_salary.loc[top_countries]
job_title = ['Data Analyst','Data Engineer','Data Scientist']
df_job_country_salary=df_job_country_salary[job_title]
df_job_country_salary.plot(kind='bar')
# Out:
# <Axes: xlabel='job_country'>

# %%
df_job_country_salary.plot(kind='bar')
plt.ylabel('Median Salary ($USD)')
plt.xlabel('')
plt.title('Median Salary By Country And Job Title ')
plt.xticks(rotation=45,ha='right')
plt.show()
