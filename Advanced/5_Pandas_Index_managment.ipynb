# %%
import pandas as pd 
import matplotlib.pyplot as plt 

data = pd.read_csv(r"C:\Users\Lenovo\OneDrive\Documents\Projects\Luke Barousse Projects\Python Course  Data Analysis\data_jobs.csv")
df=data
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.sample(5)
# Out:
#              job_title_short  \
# 495533         Data Engineer
# 188211        Data Scientist
# 736978        Data Scientist
# 142664          Data Analyst
# 83101   Senior Data Engineer
#
#                                                 job_title  \
# 495533  Data Engineer, Service Distribution - Tilburg/...
# 188211                                     Data Scientist
# 736978                                     Data Scientist
# 142664                         Business/Data Analyst (W2)
# 83101                            Senior GCP Data Engineer
#
#                   job_location                job_via job_schedule_type  \
# 495533  Amsterdam, Netherlands    via ClimateTechList         Full-time
# 188211       Winston-Salem, NC              via BeBee         Full-time
# 736978                Anywhere           via LinkedIn        Contractor
# 142664         Jersey City, NJ  via My ArkLaMiss Jobs         Full-time
# 83101                 Anywhere           via LinkedIn         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 495533               False              Netherlands 2023-10-02 23:41:48
# 188211               False   Florida, United States 2023-11-11 18:04:22
# 736978                True     Texas, United States 2023-09-26 19:04:17
# 142664               False  New York, United States 2023-02-20 14:59:59
# 83101                 True                   Canada 2023-06-08 20:33:12
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 495533                   True                 False    Netherlands
# 188211                  False                  True  United States
# 736978                  False                 False  United States
# 142664                   True                 False  United States
# 83101                   False                 False         Canada
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 495533         NaN              NaN              NaN
# 188211         NaN              NaN              NaN
# 736978        hour              NaN             68.5
# 142664         NaN              NaN              NaN
# 83101          NaN              NaN              NaN
#
#                           company_name  \
# 495533                           Tesla
# 188211  Cognizant Technology Solutions
# 736978                      SSi People
# 142664                   Matlen Silver
# 83101                        Improving
#
#                                                job_skills  \
# 495533                       ['windows', 'linux', 'flow']
# 188211  ['python', 'sql', 'databricks', 'aws', 'redshi...
# 736978                                                NaN
# 142664  ['sql', 'oracle', 'word', 'excel', 'jira', 'co...
# 83101   ['python', 'java', 'scala', 'sql', 'nosql', 's...
#
#                                           job_type_skills
# 495533    {'os': ['windows', 'linux'], 'other': ['flow']}
# 188211  {'cloud': ['databricks', 'aws', 'redshift'], '...
# 736978                                                NaN
# 142664  {'analyst_tools': ['word', 'excel'], 'async': ...
# 83101   {'analyst_tools': ['looker'], 'async': ['jira'...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=787686, step=1)

# %%
df.index.name = 'job_index'

# %%
df.head(5)
# Out:
#           job_title_short                job_title  \
# job_index
# 0            Data Analyst           Data Analytics
# 1          Data Scientist    Data Scientist Intern
# 2            Data Analyst  Manager, Data Analytics
# 3           Data Engineer            Data Engineer
# 4            Data Analyst   Technical Data Analyst
#
#                                          job_location  \
# job_index
# 0                       Monterrey, Nuevo Leon, Mexico
# 1                                    Lisbon, Portugal
# 2          Guanacaste Province, Lagunilla, Costa Rica
# 3                                    Lambayeque, Peru
# 4                                         Fairfax, VA
#
#                             job_via job_schedule_type  job_work_from_home  \
# job_index
# 0                         via BeBee         Part-time               False
# 1          via Empregos Trabajo.org         Full-time               False
# 2              via BeBee Costa Rica         Full-time               False
# 3                    via BeBee Perú         Full-time               False
# 4                        via Indeed        Contractor               False
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0                           Mexico 2023-12-05 07:26:05                  False
# 1                         Portugal 2023-08-20 07:46:51                  False
# 2                       Costa Rica 2023-11-21 08:37:14                  False
# 3                             Peru 2023-11-21 07:36:33                   True
# 4          New York, United States 2023-12-20 07:00:10                   True
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False         Mexico         NaN              NaN
# 1                         False       Portugal         NaN              NaN
# 2                         False     Costa Rica         NaN              NaN
# 3                         False           Peru         NaN              NaN
# 4                         False  United States         NaN              NaN
#
#            salary_hour_avg                           company_name  \
# job_index
# 0                      NaN  2U Bootcamps Instructional Engagement
# 1                      NaN                                  Nokia
# 2                      NaN               Thermo Fisher Scientific
# 3                      NaN                                Emprego
# 4                      NaN                       Info Origin Inc.
#
#                                                   job_skills  \
# job_index
# 0          ['go', 'python', 'mongodb', 'mongodb', 'css', ...
# 1          ['sql', 'python', 'sql server', 'oracle', 'azu...
# 2                                                        NaN
# 3                                                        NaN
# 4                                  ['sql', 'python', 'jira']
#
#                                              job_type_skills
# job_index
# 0          {'analyst_tools': ['tableau'], 'databases': ['...
# 1          {'analyst_tools': ['sap'], 'cloud': ['oracle',...
# 2                                                        NaN
# 3                                                        NaN
# 4          {'async': ['jira'], 'programming': ['sql', 'py...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df_usa= df[df['job_country'] == "United States"]

# %%
df_usa.head(5)
# Out:
#    job_index job_title_short  \
# 0          4    Data Analyst
# 1          6  Data Scientist
# 2          7  Data Scientist
# 3         14  Data Scientist
# 4         16   Data Engineer
#
#                                            job_title    job_location  \
# 0                             Technical Data Analyst     Fairfax, VA
# 1               Research Data Scientist - Now Hiring  Washington, DC
# 2  Diversity and Inclusion Workforce Data Scienti...   United States
# 3                                     Data Scientist     Hampton, VA
# 4                   Staff Data Engineer - Now Hiring       Plano, TX
#
#         job_via        job_schedule_type  job_work_from_home  \
# 0    via Indeed               Contractor               False
# 1  via Snagajob                Full-time               False
# 2     via BeBee                Full-time               False
# 3   via Monster                Full-time               False
# 4  via Snagajob  Full-time and Part-time               False
#
#            search_location     job_posted_date  job_no_degree_mention  \
# 0  New York, United States 2023-12-20 07:00:10                   True
# 1  New York, United States 2023-02-01 07:03:49                  False
# 2     Texas, United States 2023-07-27 07:04:35                  False
# 3                  Georgia 2023-04-10 07:54:26                  False
# 4     Texas, United States 2023-12-28 07:26:45                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States         NaN              NaN
# 1                  True  United States         NaN              NaN
# 2                 False  United States         NaN              NaN
# 3                  True  United States         NaN              NaN
# 4                 False  United States        hour              NaN
#
#    salary_hour_avg         company_name  \
# 0              NaN     Info Origin Inc.
# 1              NaN  Booz Allen Hamilton
# 2              NaN            CIDIS LLC
# 3              NaN           Guidehouse
# 4        57.060001            FinThrive
#
#                                           job_skills  \
# 0                          ['sql', 'python', 'jira']
# 1     ['python', 'r', 'tableau', 'splunk', 'docker']
# 2  ['python', 'r', 'sql', 'cognos', 'alteryx', 't...
# 3         ['sql', 'r', 'python', 'excel', 'tableau']
# 4  ['python', 'scala', 'sql', 'bash', 'shell', 's...
#
#                                      job_type_skills
# 0  {'async': ['jira'], 'programming': ['sql', 'py...
# 1  {'analyst_tools': ['tableau', 'splunk'], 'othe...
# 2  {'analyst_tools': ['cognos', 'alteryx', 'table...
# 3  {'analyst_tools': ['excel', 'tableau'], 'progr...
# 4  {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
df_usa.reset_index(inplace=True)

# %%
df_usa.head(5)
# Out:
#    job_index job_title_short  \
# 0          4    Data Analyst
# 1          6  Data Scientist
# 2          7  Data Scientist
# 3         14  Data Scientist
# 4         16   Data Engineer
#
#                                            job_title    job_location  \
# 0                             Technical Data Analyst     Fairfax, VA
# 1               Research Data Scientist - Now Hiring  Washington, DC
# 2  Diversity and Inclusion Workforce Data Scienti...   United States
# 3                                     Data Scientist     Hampton, VA
# 4                   Staff Data Engineer - Now Hiring       Plano, TX
#
#         job_via        job_schedule_type  job_work_from_home  \
# 0    via Indeed               Contractor               False
# 1  via Snagajob                Full-time               False
# 2     via BeBee                Full-time               False
# 3   via Monster                Full-time               False
# 4  via Snagajob  Full-time and Part-time               False
#
#            search_location     job_posted_date  job_no_degree_mention  \
# 0  New York, United States 2023-12-20 07:00:10                   True
# 1  New York, United States 2023-02-01 07:03:49                  False
# 2     Texas, United States 2023-07-27 07:04:35                  False
# 3                  Georgia 2023-04-10 07:54:26                  False
# 4     Texas, United States 2023-12-28 07:26:45                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States         NaN              NaN
# 1                  True  United States         NaN              NaN
# 2                 False  United States         NaN              NaN
# 3                  True  United States         NaN              NaN
# 4                 False  United States        hour              NaN
#
#    salary_hour_avg         company_name  \
# 0              NaN     Info Origin Inc.
# 1              NaN  Booz Allen Hamilton
# 2              NaN            CIDIS LLC
# 3              NaN           Guidehouse
# 4        57.060001            FinThrive
#
#                                           job_skills  \
# 0                          ['sql', 'python', 'jira']
# 1     ['python', 'r', 'tableau', 'splunk', 'docker']
# 2  ['python', 'r', 'sql', 'cognos', 'alteryx', 't...
# 3         ['sql', 'r', 'python', 'excel', 'tableau']
# 4  ['python', 'scala', 'sql', 'bash', 'shell', 's...
#
#                                      job_type_skills
# 0  {'async': ['jira'], 'programming': ['sql', 'py...
# 1  {'analyst_tools': ['tableau', 'splunk'], 'othe...
# 2  {'analyst_tools': ['cognos', 'alteryx', 'table...
# 3  {'analyst_tools': ['excel', 'tableau'], 'progr...
# 4  {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
df_usa.reset_index(inplace=True)

df_usa.set_index('job_index',inplace = True)

# %%
df_usa.head(4)
# Out:
#           job_title_short                                          job_title  \
# job_index
# 4            Data Analyst                             Technical Data Analyst
# 6          Data Scientist               Research Data Scientist - Now Hiring
# 7          Data Scientist  Diversity and Inclusion Workforce Data Scienti...
# 14         Data Scientist                                     Data Scientist
#
#              job_location       job_via job_schedule_type  job_work_from_home  \
# job_index
# 4             Fairfax, VA    via Indeed        Contractor               False
# 6          Washington, DC  via Snagajob         Full-time               False
# 7           United States     via BeBee         Full-time               False
# 14            Hampton, VA   via Monster         Full-time               False
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 4          New York, United States 2023-12-20 07:00:10                   True
# 6          New York, United States 2023-02-01 07:03:49                  False
# 7             Texas, United States 2023-07-27 07:04:35                  False
# 14                         Georgia 2023-04-10 07:54:26                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 4                         False  United States         NaN              NaN
# 6                          True  United States         NaN              NaN
# 7                         False  United States         NaN              NaN
# 14                         True  United States         NaN              NaN
#
#            salary_hour_avg         company_name  \
# job_index
# 4                      NaN     Info Origin Inc.
# 6                      NaN  Booz Allen Hamilton
# 7                      NaN            CIDIS LLC
# 14                     NaN           Guidehouse
#
#                                                   job_skills  \
# job_index
# 4                                  ['sql', 'python', 'jira']
# 6             ['python', 'r', 'tableau', 'splunk', 'docker']
# 7          ['python', 'r', 'sql', 'cognos', 'alteryx', 't...
# 14                ['sql', 'r', 'python', 'excel', 'tableau']
#
#                                              job_type_skills
# job_index
# 4          {'async': ['jira'], 'programming': ['sql', 'py...
# 6          {'analyst_tools': ['tableau', 'splunk'], 'othe...
# 7          {'analyst_tools': ['cognos', 'alteryx', 'table...
# 14         {'analyst_tools': ['excel', 'tableau'], 'progr...

# %%
median_pivot=df_usa.pivot_table(values='salary_year_avg',index='job_title_short',aggfunc=['median','min','max'])

# %%
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   115000.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                125000.0         48982.0        375000.0

# %%
median_pivot.sort_values(by=('median','salary_year_avg'), ascending=False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            155000.0         55000.0        475000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Software Engineer                125000.0         48982.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Cloud Engineer                   115000.0         42000.0        221844.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Business Analyst                  90000.0         35000.0        387460.0
# Data Analyst                      90000.0         25000.0        375000.0

# %%
median_pivot.sort_index(inplace=True)
