# %%
import pandas as pd 
import matplotlib.pyplot as plt 

data = pd.read_csv(r"C:\Users\Lenovo\OneDrive\Documents\Projects\Luke Barousse Projects\Python Course  Data Analysis\data_jobs.csv")
df=data
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df['job_posted_month']= df['job_posted_date'].dt.strftime('%b')

# %%
df
# Out:
#              job_title_short  \
# 0               Data Analyst
# 1             Data Scientist
# 2               Data Analyst
# 3              Data Engineer
# 4               Data Analyst
# ...                      ...
# 787681  Senior Data Engineer
# 787682          Data Analyst
# 787683         Data Engineer
# 787684     Software Engineer
# 787685  Senior Data Engineer
#
#                                                 job_title  \
# 0                                          Data Analytics
# 1                                   Data Scientist Intern
# 2                                 Manager, Data Analytics
# 3                                           Data Engineer
# 4                                  Technical Data Analyst
# ...                                                   ...
# 787681  (Senior) Data Engineer (m/w/d) - PUBLIC BW / C...
# 787682                                  Lead Data Analyst
# 787683                                 Lead Data Engineer
# ...

# %%
months = df['job_posted_month'].unique()
{month :month for month in months}
# Out:
# {'Dec': 'Dec',
#  'Aug': 'Aug',
#  'Nov': 'Nov',
#  'Jul': 'Jul',
#  'Feb': 'Feb',
#  'May': 'May',
#  'Jun': 'Jun',
#  'Apr': 'Apr',
#  'Mar': 'Mar',
#  'Sep': 'Sep',
#  'Jan': 'Jan',
#  'Oct': 'Oct'}

# %%
dict_month={month : df[df['job_posted_month'] == month ]for month in months}

# %%
dict_month['Jan']
# Out:
#              job_title_short                                        job_title  \
# 24            Data Scientist                       Spezialist Data Management
# 27      Senior Data Engineer                             SENIOR DATA ENGINEER
# 36            Data Scientist                                   Data Scientist
# 55          Business Analyst                   Business Analyst at Lipa Later
# 56             Data Engineer                                    Data Engineer
# ...                      ...                                              ...
# 787622     Software Engineer                            Azure DevOps Engineer
# 787623          Data Analyst                                     Data Analyst
# 787624     Software Engineer  Senior Software Engineer- Integrations (Remote)
# 787627         Data Engineer                                    Data Engineer
# 787628  Senior Data Engineer                             Senior Data Engineer
#
# ...

# %% [markdown]
# Boss Needs 2023 Quater 1

# %%
df_q1=pd.concat([dict_month['Jan'],dict_month['Feb'],dict_month['Mar']],ignore_index=True)

# %%
df_q1['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>

# %% [markdown]
# Different Methods to Export the Data

# %%
df_q1.head(5).to_clipboard()

# %%
#	job_title_short	job_title	job_location	job_via	job_schedule_type	job_work_from_home	search_location	job_posted_date	job_no_degree_mention	job_health_insurance	job_country	salary_rate	salary_year_avg	salary_hour_avg	company_name	job_skills	job_type_skills	job_posted_month
#0	Data Scientist	Spezialist Data Management	Vienna, Austria	via BeBee	Full-time	False	Austria	2023-01-08 07:15:50	False	False	Austria				Santander Consumer Bank	['sas', 'sas', 'sql']	{'analyst_tools': ['sas'], 'programming': ['sas', 'sql']}	Jan
#1	Senior Data Engineer	SENIOR DATA ENGINEER	Gaydon, Warwick, UK	via My ArkLaMiss Jobs	Full-time	False	United Kingdom	2023-01-16 07:54:17	True	False	United Kingdom				Jaguar Land Rover	['python', 'sql', 'no-sql', 'bigquery', 'airflow', 'tableau', 'looker', 'power bi', 'flow', 'kubernetes', 'git', 'docker']	{'analyst_tools': ['tableau', 'looker', 'power bi'], 'cloud': ['bigquery'], 'libraries': ['airflow'], 'other': ['flow', 'kubernetes', 'git', 'docker'], 'programming': ['python', 'sql', 'no-sql']}	Jan
#2	Data Scientist	Data Scientist	Manchester, UK	via Jobs Trabajo.org	Full-time	False	United Kingdom	2023-01-20 07:57:09	False	False	United Kingdom				Wejo	['python', 'scala', 'sql', 'r', 'hadoop', 'spark']	{'libraries': ['hadoop', 'spark'], 'programming': ['python', 'scala', 'sql', 'r']}	Jan
#3	Business Analyst	Business Analyst at Lipa Later	Nairobi, Kenya	via BeBee Kenya	Full-time	False	Kenya	2023-01-31 07:58:54	False	False	Kenya				Lipa Later	['python', 'r', 'sql', 'excel']	{'analyst_tools': ['excel'], 'programming': ['python', 'r', 'sql']}	Jan
#4	Data Engineer	Data Engineer	Anywhere	via EchoJobs	Full-time	True	New York, United States	2023-01-08 07:04:55	False	True	United States	year	120000.0		BioIntelliSense	['sql', 'python', 'databricks', 'spark', 'airflow']	{'cloud': ['databricks'], 'libraries': ['spark', 'airflow'], 'programming': ['sql', 'python']}	Jan

# %%
df_q1.to_csv('quarter_1.csv')

# %%
pd.read_csv('quarter_1.csv', index_col=0)
# Out:
#              job_title_short  \
# 0             Data Scientist
# 1       Senior Data Engineer
# 2             Data Scientist
# 3           Business Analyst
# 4              Data Engineer
# ...                      ...
# 220971  Senior Data Engineer
# 220972          Data Analyst
# 220973         Data Engineer
# 220974     Software Engineer
# 220975  Senior Data Engineer
#
#                                                 job_title  \
# 0                              Spezialist Data Management
# 1                                    SENIOR DATA ENGINEER
# 2                                          Data Scientist
# 3                          Business Analyst at Lipa Later
# 4                                           Data Engineer
# ...                                                   ...
# 220971  (Senior) Data Engineer (m/w/d) - PUBLIC BW / C...
# 220972                                  Lead Data Analyst
# 220973                                 Lead Data Engineer
# ...

# %%
df_q1.to_excel('quarter_1.xlsx')

# %%
df_q1.to_parquet('jobs_data.parquet')
df_q1.to_pickle('jobs_data.pkl')
